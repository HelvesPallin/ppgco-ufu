# %%
# %run ..\main\functions.ipynb

img = cv2.imread("img/skull/ctskull-256.tif", cv2.IMREAD_GRAYSCALE)
img7 = img_requantization(img, 7)
img6 = img_requantization(img, 6)
img5 = img_requantization(img, 5)
img4 = img_requantization(img, 4)
img3 = img_requantization(img, 3)
img2 = img_requantization(img, 2)
img1 = img_requantization(img, 1)

cv2.imwrite("img/skull/ctskull-128.tif", img7)
cv2.imwrite("img/skull/ctskull-64.tif", img6)
cv2.imwrite("img/skull/ctskull-32.tif", img5)
cv2.imwrite("img/skull/ctskull-16.tif", img4)
cv2.imwrite("img/skull/ctskull-8.tif", img3)
cv2.imwrite("img/skull/ctskull-4.tif", img2)
cv2.imwrite("img/skull/ctskull-2.tif", img1)

plt.subplot(1, 8, 1)
plt.imshow(img, cmap='gray', vmin=0, vmax=255)
plt.subplot(1, 8, 2)
plt.imshow(img7, cmap='gray', vmin=0, vmax=255)
plt.subplot(1, 8, 3)
plt.imshow(img6, cmap='gray', vmin=0, vmax=255)
plt.subplot(1, 8, 4)
plt.imshow(img5, cmap='gray', vmin=0, vmax=255)
plt.subplot(1, 8, 5)
plt.imshow(img4, cmap='gray', vmin=0, vmax=255)
plt.subplot(1, 8, 6)
plt.imshow(img3, cmap='gray', vmin=0, vmax=255)
plt.subplot(1, 8, 7)
plt.imshow(img2, cmap='gray', vmin=0, vmax=255)
plt.subplot(1, 8, 8)
plt.imshow(img1, cmap='gray', vmin=0, vmax=255)
