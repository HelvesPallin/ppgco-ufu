# %%
# %run ..\main\functions.ipynb

img = cv2.imread("img/relogio/relogio.tif", cv2.IMREAD_GRAYSCALE)

print('Tamanho da imagem 1250dpi: ',img.shape)

img300dpi = img_resampling(img,4)
cv2.imwrite("img/relogio/relogio300.tif", img300dpi)
img150dpi = img_resampling(img300dpi,2)
cv2.imwrite("img/relogio/relogio150.tif", img150dpi)
img72dpi = img_resampling(img150dpi,2)
cv2.imwrite("img/relogio/relogio72.tif", img72dpi)
print('Tamanho da imagem 300dpi: ',img300dpi.shape)
print('Tamanho da imagem 150dpi: ',img150dpi.shape)
print('Tamanho da imagem 72dpi: ',img72dpi.shape)

plt.subplot(1, 4, 1)
plt.imshow(img, cmap='gray', vmin=0, vmax=255)
plt.subplot(1, 4, 2)
plt.imshow(img300dpi, cmap='gray', vmin=0, vmax=255)
plt.subplot(1, 4, 3)
plt.imshow(img150dpi, cmap='gray', vmin=0, vmax=255)
plt.subplot(1, 4, 4)
plt.imshow(img72dpi, cmap='gray', vmin=0, vmax=255)
# Out:
# Tamanho da imagem 1250dpi:  (3692, 2812)
# Tamanho da imagem 300dpi:  (923, 703)
# Tamanho da imagem 150dpi:  (462, 352)
# Tamanho da imagem 72dpi:  (231, 176)
